# %%
import os
import io
import pandas as pd
import numpy as np
import subprocess
import matplotlib.pyplot as plt

# %%
MC1R = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/MC1R/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
TYR = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/TYR/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
MTAP = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/MTAP/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
CASP8 = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/CASP8/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
OCA2 = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/OCA2/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
CCND1 = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/CCND1/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
CDH1 = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/CDH1/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-906eec50d759> in <module>
#       1 MC1R = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/MC1R/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
# ----> 2 TYR = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/TYR/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
#       3 MTAP = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/MTAP/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
#       4 CASP8 = pd.read_csv('/mnt/Genoma/drobles/ccastaneda/gwas-reseq/lcr_filtered/regions/CASP8/table_for_paper.csv', header = None).rename(columns = {0:'POS'}).set_index('POS')
# ...

# %%
region = str(input("enter the region you want to make a table for:"))
wd = '/mnt/Genoma/drobles/ccastaneda/gwas-reseq/regions/'+region
os.chdir(wd)

# %%
r1 = pd.read_csv('r1').drop_duplicates('Existing_variation')
r2 = pd.read_csv('r2').drop_duplicates('Existing_variation')
leads = pd.read_csv('to_condition', header = None)

# %%
r1['38POS'] = r1.GRCh38.str.split('-').str.get(0)
r2['38POS'] = r2.GRCh38.str.split('-').str.get(0)

# %%
leads = leads.rename(columns = {0:'38POS'})
leads['GRCh38'] = leads['38POS'] + '-' + leads['38POS'].str.split(':').str.get(1)

# %%
r1_positions = r1['GRCh38']
r2_positions = r2['GRCh38']
leads_positions = leads['GRCh38']

# %%
df = pd.concat([r1_positions, r2_positions, leads_positions], axis=0)

# %%
df = df.to_frame().reset_index().drop(axis = 1, labels = 'index')
df.to_csv('haplotypes_38.bed')

# %%
s = r1.merge(r2, how = 'outer')

# %%
s
# Out:
#   Signal Region       Existing_variation                   GRCh38 ref_alt  \
# 0     s1   MC1R                rs1108064  chr16:89827742-89827742     C_G
# 1     s1   MC1R       rs1805007&CM981238  chr16:89919709-89919709     T_C
# 2     s1   MC1R               rs74800773  chr16:89958562-89958562     G_C
# 3     s1   MC1R               rs45610233  chr16:89981987-89981987     T_C
# 4     s1   MC1R               rs73283859  chr16:89996112-89996112     C_G
# 5     s2   MC1R   rs1800282&COSV66881217  chr16:89816599-89816599     NaN
# 6     s2   MC1R  rs11538871&COSV54528897  chr16:89911337-89911337     NaN
# 7     s2   MC1R               rs74415461  chr16:89924435-89924435     NaN
# 8     s2   MC1R               rs74465604  chr16:89942655-89942655     NaN
#
#    -logP_fisher                              Consequence  Protein_position  \
# 0      3.561616                    upstream_gene_variant               NaN
# 1     11.147276                    upstream_gene_variant               NaN
# ...
